# %%
#Task 1: Menu of Options

print("Welcome to the PyWorld!\nHere you need to choose your options.\nThe menu options are: ")
print("""
1.What is the current time
2.What is the current time in UNIX format
3.convert userinput date to datetime object
4.Is the current year Leap year + time until next Leap year
5.timedelta submenu
6.calendar
7.timezones
8.Time at opposite side of the world
9.Joker
10.

""")
c1=input("Enter yor choice1: ")
if c1==1:
    print("Your choice was to see the current time")
    from datetime import datetime
    now = datetime.now()
    time = now.strftime("%H:%M:%S%p")
    print(f'The current time is {time}')

elif c1==2:
    print("Your choice was to see the current time in UNIX format")
    import time
    now = time.time()
    print(f'The current time in UNIX format is {now}')

elif c1==3:
    print("Your choice was to convert string to datetime object")
    from datetime import datetime
    u = input("Enter the date:")
    result = datetime.strptime(u, "%b %d %Y %I:%M%p")
    t = type(result)
    print(f'The Date and time you entered was {u} and it is converted to {result} and now it is of the type {t}')

elif c1==4:
    print("Your choice was to check if current year is leap year")
    from datetime import datetime
    import calendar
    now = datetime.now()

    y = now.strftime("%Y")
    print(y)

    if calendar.isleap(y) == True:
    print("The year {y} is a leap year and the next leap year is {y}{+ 4}")
    """else:
    while False:
        new_y= y+1
        if(new_y %4 ==0 and new_y%100!=0) or new_y%400 ==0:
            break

    print("The year {y} is  NOT a leap year and time until the next leap year is {}")"""

elif c1==5:
    print("Your choice was to create a timedelta object to see difference between given datetime and now")
    from datetime import datetime, timedelta
    u = input("Enter a past Date and Time (YYYY-MM-DD HH:MM:SS)")
    udatetime = datetime.strptime(u, "%Y-%m-%d %H-%M-%S")
    current_datetime = datetime.now()
    delta = current_datetime - udatetime
    option = input("Enter your unit(years/months/days/hours/minutes/seconds)")
    y = (delta.days)/365
    if option == "years":
        print(f"Time difference is {y} years")
    elif option == "months":
        print(f"Time difference is {(y*12)} months")
    elif option == "days":
        print(f"Time difference is {delta.days} days")    
    elif option == "hours":
        print(f"Time difference is {(delta.days)*24} hours")   
    elif option == "minutes":
        print(f"Time difference is {(delta.days)*24*60} minutes") 
    else: 
        print(f"Time difference is {delta.seconds} seconds")


elif c1==6:
    print("Your choice was to print a calendar for the current month")
    import calendar
    datenow = datetime.now()
    year = datenow.year
    month = datenow.month
    print(calendar.month(year,month))

elif c1==7:
    print("Your choice was to display current time in different timezones")
    from datetime import timezone
    import pytz
    time_mylocation = datetime.now()
    userlocation = input("""Enter your location:
                            Tokyo / Japan
                            Dublin / Ireland
                            San Francisco / USA
                            Berlin / Germany
                            Johannesburg / South Africa
                            """)
    ny_tz = pytz.timezone('America/New_York')
    
if option == "Tokyo":
        tt =time_mylocation.astimezone(timezone('Japan'))
        print(f"The current time in Tokyo is {tt} ")
elif option == "Dublin":
        td =time_mylocation.astimezone(timezone('Europe/Dublin'))
        print(f"The current time in Dublin is {td}")
elif option == "San Francisco":
        ts =time_mylocation.astimezone(timezone('America/Los_  Angeles'))
        print(f"The current time in San Francisco is {ts}")    
elif option == "Berlin":
        tb =time_mylocation.astimezone(timezone('Europe/Berlin'))
        print(f"The current time in Berlin is {tb}")   
elif option == "Johannesburg ":
        tj =time_mylocation.astimezone(timezone('Africa/Johannesburg'))
        print(f"The current time in Johannesburg is {tj}") 
else: 
        print("Please select correct options")

# %%
print("Your choice was to display current time in different timezones")
from datetime import timezone

time_mylocation = datetime.now()
option = input("""Enter your location:
                            1.Tokyo / Japan
                            2.Dublin / Ireland
                            3.San Francisco / USA
                            4.Berlin / Germany
                            5.Johannesburg / South Africa
                            """)
    
if option == "1":
        tt =time_mylocation.astimezone(timezone('Japan'))
        print(f"The current time in Tokyo is {datetime.strftime(tt,'%H:%m')} ")
elif option == "2":
        td =time_mylocation.astimezone(timezone('Europe/Dublin'))
        print(f"The current time in Dublin is {datetime.strftime(td,'%H:%m')}")
elif option == "3":
        ts =time_mylocation.astimezone(timezone('America/Los_  Angeles'))
        print(f"The current time in San Francisco is {datetime.strftime(ts,'%H:%m')}")    
elif option == "4":
        tb =time_mylocation.astimezone(timezone('Europe/Berlin'))
        print(f"The current time in Berlin is {datetime.strftime(tb,'%H:%m')}")   
elif option == "5":
        tj =time_mylocation.astimezone(timezone('Africa/Johannesburg'))
        print(f"The current time in Johannesburg is {datetime.strftime(tj,'%H:%m')}") 
else: 
        print("Please select correct options")
# Out:
# Your choice was to display current time in different timezones
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 23
#      21         print(f"The current time in San Francisco is {datetime.strftime(ts,'%H:%m')}")
#      22 elif option == "4":
# ---> 23         tb =time_mylocation.astimezone(timezone('Europe/Berlin'))
#      24         print(f"The current time in Berlin is {datetime.strftime(tb,'%H:%m')}")
#      25 elif option == "5":
#
# TypeError: timezone() argument 1 must be datetime.timedelta, not str

# %%
now = datetime.now()

tb =now.astimezone(timezone('Europe/Berlin'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 now = datetime.now()
# ----> 3 tb =now.astimezone(timezone('Europe/Berlin'))
#
# TypeError: timezone() argument 1 must be datetime.timedelta, not str
